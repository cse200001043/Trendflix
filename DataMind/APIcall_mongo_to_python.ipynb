# %%
import csv
import pandas as pd
import pymongo

# %% [markdown]
# # Creating Connection

# %%
client = pymongo.MongoClient("mongodb+srv://admin-harshit:alumni30@alumniportal.2aiihq6.mongodb.net/cinemania?retryWrites=true&w=majority")

# %%
db=client['cinemania']

# %%
collection=db['dataset']

# %% [markdown]
# # Inserting Data

# %%
original_df = pd.read_csv("./datasets/final_dataset.csv")
print(original_df)
# Out:
#       movie_id                   movie_title  \
# 0          238                 The Godfather
# 1          278      The Shawshank Redemption
# 2          240         The Godfather Part II
# 3          424              Schindler's List
# 4        19404   Dilwale Dulhania Le Jayenge
# ...        ...                           ...
# 7981    452015                 Psychokinesis
# 7982     43930  Tomorrow, When the War Began
# 7983     13474                            P2
# 7984     13200                           Red
# 7985     11557               St. Elmo's Fire
#
#                                                overview  \
# 0     Spanning the years 1945 to 1955, a chronicle o...
# 1     Framed in the 1940s for the double murder of h...
# 2     In the continuing saga of the Corleone crime f...
# 3     The true story of how businessman Oskar Schind...
# 4     Raj is a rich, carefree, happy-go-lucky second...
# ...                                                 ...
# ...

# %%
import ast
# original_df['genre'] = original_df['genre'].apply(ast.literal_eval)
original_df['genre'][0][0]
# Out:
# {'id': 18, 'name': 'Drama'}

# %%
data = []
with open("./datasets/modified_dataset.csv", 'r', encoding='utf-8') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    for row in csv_reader:
        data.append(row)

# %%
collection.insert_many(data)

# %% [markdown]
# # Fetching Data

# %%
data = list(collection.find())

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                            _id movie_id                      movie_title  \
# 0     650e6d87402f0bada82577e4        5                       Four Rooms
# 1     650e6d87402f0bada82577e5       11                        Star Wars
# 2     650e6d87402f0bada8257814      105               Back to the Future
# 3     650e6d87402f0bada82577ec       25                          Jarhead
# 4     650e6d87402f0bada82577e6       12                     Finding Nemo
# ...                        ...      ...                              ...
# 6349  650e6d87402f0bada825908f   556803              The Princess Switch
# 6350  650e6d87402f0bada825909c   556901  Teen Titans Go! vs. Teen Titans
# 6351  650e6d87402f0bada82590af   491480   The Boy Who Harnessed the Wind
# 6352  650e6d87402f0bada82590b1   524251                        I See You
# 6353  650e6d87402f0bada82590b4   425972                            Cargo
#
#                                                overview  \
# ...

# %%
original_df['genre'][0]
# original_df['genre']
# Out:
# "[{'id': 80, 'name': 'Crime'}, {'id': 35, 'name': 'Comedy'}]"
